# %%
import pandas as pd

df = pd.read_csv("data/raw/orders.csv")
df
# Out:
#          order_id customer_id  order_date   ship_date delivery_date  \
# 0      ORD1000000  CUST101392  2025-10-28  2025-10-28    2025-10-28
# 1      ORD1000001  CUST117918  2025-04-22  2025-04-23    2025-04-26
# 2      ORD1000002  CUST111893  2025-08-01  2025-08-02           NaN
# 3      ORD1000003  CUST110447  2025-11-24  2025-11-26    2025-11-28
# 4      ORD1000004  CUST102862  2025-01-15  2025-01-16    2025-01-18
# ...           ...         ...         ...         ...           ...
# 50120  ORD1027678  CUST132003  2024-01-15  2024-01-15    2024-01-15
# 50121  ORD1010704  CUST101039  2024-04-02  2024-04-02    2024-04-02
# 50122  ORD1033461  CUST128428  2026-04-25  2026-04-26    2026-04-29
# 50123  ORD1022001  CUST105020  2024-02-04  2024-02-04    2024-02-09
# 50124  ORD1030170  CUST122477  2024-10-26  2024-10-26    2024-10-29
#
#              customer_name customer_segment customer_country customer_city  \
# ...

# %%
df.isnull()
# Out:
#        order_id  customer_id  order_date  ship_date  delivery_date  \
# 0         False        False       False      False          False
# 1         False        False       False      False          False
# 2         False        False       False      False           True
# 3         False        False       False      False          False
# 4         False        False       False      False          False
# ...         ...          ...         ...        ...            ...
# 50120     False        False       False      False          False
# 50121     False        False       False      False          False
# 50122     False        False       False      False          False
# 50123     False        False       False      False          False
# 50124     False        False       False      False          False
#
#        customer_name  customer_segment  customer_country  customer_city  \
# 0              False             False             False          False
# ...
